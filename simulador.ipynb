# %%
from math import *
from math import radians
import numpy as np 
import matplotlib.pyplot as plt

# %%
print('Simulador de Tiro Parabolico'.center(100,'-'))
while True:
    try:
        Vi=float(input('Ingresa la velocidad inicial del proyectil (m/s): '))
        break
    except Exception:
        print('Datos incorrectos')
print(f'\n la velocidad inicial es de {Vi}m/s^2')
while True:
    try:
        angulo=float(input('Ingrese el angulo de la trayectoria del proyectil:')) 
        break
    except Exception:
        print('datos incorrectos')
print(f'\nEl angulo de trajectoria es de {angulo}°')

grados = (angulo*3.1416)/180

while True:
    try:
        g=float(input('Ingrese el valor de la gravedad (m/s^2)'))
        break
    except Exception:
        print('datos incorrectos')
print(f'\nEl valor de la gravedad es de {g} m/s^2\n')
while True:
    try:
        xo=float(input('Ingresa la posicion en el eje x'))
        break
    except Exception:
        print('datos incorrectos')
while True:
    try:
        yo=float(input('Ingresa la posicion en el eje y'))
        break
    except Exception:
        print('datos incorrectos')


a = tan(grados)
b = ((g)/(2*Vi**2)*cos(grados)**2)
ymax =(Vi**2)*(np.sin(grados)*sin(grados))/(2*g)
xmax =(Vi**2)*(np.sin(2*grados))/(g)
vho = Vi*(cos(radians(angulo)))
vver = Vi*(sin(radians(angulo)))

print('---------'.center(100,'-'))

tmax =(Vi*sin(grados))/(g)
tv =2*(tmax)
print(f'la altura maxima del proyectil............{ymax:.2f} m')
print(f'Distancia maxima recorrida hasta el impacto del proyectil........{xmax:.2f} m')
print(f'Tiempo de vuelo del proyectil......{tv:.2f} s')
# Out:
# ------------------------------------Simulador de Tiro Parabolico------------------------------------
#
#  la velocidad inicial es de 82.0m/s^2
#
# El angulo de trajectoria es de 30.6°
#
# El valor de la gravedad es de 9.81 m/s^2
#
# ----------------------------------------------------------------------------------------------------
# la altura maxima del proyectil............88.80 m
# Distancia maxima recorrida hasta el impacto del proyectil........600.64 m
# Tiempo de vuelo del proyectil......8.51 s

# %%
def f(x):
   return(a*(x)-b*(x)**2)
x=np.linspace(0,xmax,500)
y=np.linspace(0,ymax,500)



plt.title("Grafica de altura",fontsize=30,color="black",)


plt.ylabel("ALTURA",fontsize=30,color="red")                                     
plt.grid(True)                                                              
plt.grid(color = '0.5', linestyle = '--', linewidth = 1)


plt.plot(y,label= "altura")


plt.show()

# %%
def f(x):
   return(a*(x)-b*(x)**2)
x=np.linspace(0,xmax,500)


plt.title("Grafica de la dstancia",fontsize=30,color="black",)


plt.ylabel("Distancia",fontsize=30,color="red")                                     
plt.grid(True)                                                              
plt.grid(color = '0.5', linestyle = '--', linewidth = 1)


plt.plot(x,label= "Distancia")
